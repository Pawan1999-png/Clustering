# %%
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sn

# %%
# !pip install scipy
# !pip install sklearn

# %%
data=pd.read_excel("C:/Users/Public/datascience assignment/Clustering/EastWestAirlines.xlsx",sheet_name='data')
data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
data=data.rename({'ID#':'ID','Award?':'Award' },axis=1 )

# %%
data.head()
# Out:
#    ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0   1    28143           0          1          1          1          174
# 1   2    19244           0          1          1          1          215
# 2   3    41354           0          1          1          1         4123
# 3   4    14776           0          1          1          1          500
# 4   5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award
# 0            1                  0                0               7000      0
# 1            2                  0                0               6968      0
# 2            4                  0                0               7034      0
# 3            1                  0                0               6952      0
# 4           26               2077                4               6935      1

# %%
data2=data.drop(['ID'],axis=1)
data2.head()
# Out:
#    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    28143           0          1          1          1          174
# 1    19244           0          1          1          1          215
# 2    41354           0          1          1          1         4123
# 3    14776           0          1          1          1          500
# 4    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award
# 0            1                  0                0               7000      0
# 1            2                  0                0               6968      0
# 2            4                  0                0               7034      0
# 3            1                  0                0               6952      0
# 4           26               2077                4               6935      1

# %%
#Hierarchical clustering
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
df_norm = norm_func(data2.iloc[:,1:])

# %%
df_norm
# Out:
#       Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  Bonus_trans  \
# 0            0.0       0.00        0.0        0.0     0.000660     0.011628
# 1            0.0       0.00        0.0        0.0     0.000815     0.023256
# 2            0.0       0.00        0.0        0.0     0.015636     0.046512
# 3            0.0       0.00        0.0        0.0     0.001896     0.011628
# 4            0.0       0.75        0.0        0.0     0.164211     0.302326
# ...          ...        ...        ...        ...          ...          ...
# 3994         0.0       0.00        0.0        0.0     0.032330     0.046512
# 3995         0.0       0.00        0.0        0.0     0.003720     0.058140
# 3996         0.0       0.50        0.0        0.0     0.096505     0.093023
# 3997         0.0       0.00        0.0        0.0     0.001896     0.011628
# 3998         0.0       0.00        0.0        0.0     0.000000     0.000000
#
# ...

# %%
dendrogram=sch.dendrogram(sch.linkage(df_norm,method='single'))

# %%
hc=AgglomerativeClustering(n_clusters=4,affinity='euclidean',linkage='single')
hc
# Out:
# AgglomerativeClustering(linkage='single', n_clusters=4)

# %%
y_hc=hc.fit_predict(df_norm)
clusters=pd.DataFrame(y_hc,columns=['cluster'])

# %%
clusters
# Out:
#       cluster
# 0           1
# 1           1
# 2           1
# 3           1
# 4           0
# ...       ...
# 3994        0
# 3995        0
# 3996        0
# 3997        1
# 3998        1
#
# [3999 rows x 1 columns]

# %%
df_row = pd.concat([data2, clusters],axis=1)
df_row
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
df_row.cluster.value_counts()
# Out:
# 1    2518
# 0    1479
# 3       1
# 2       1
# Name: cluster, dtype: int64

# %%
#k-means
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i,random_state=0)
    kmeans.fit(df_norm)
    wcss.append(kmeans.inertia_)
    
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
model=KMeans(n_clusters=4)
model.fit(df_norm)
model.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
md=pd.Series(model.labels_)
data['clust']=md
df_norm.head()
# Out:
#    Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  Bonus_trans  \
# 0         0.0       0.00        0.0        0.0     0.000660     0.011628
# 1         0.0       0.00        0.0        0.0     0.000815     0.023256
# 2         0.0       0.00        0.0        0.0     0.015636     0.046512
# 3         0.0       0.00        0.0        0.0     0.001896     0.011628
# 4         0.0       0.75        0.0        0.0     0.164211     0.302326
#
#    Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award
# 0           0.000000         0.000000           0.843742    0.0
# 1           0.000000         0.000000           0.839884    0.0
# 2           0.000000         0.000000           0.847842    0.0
# 3           0.000000         0.000000           0.837955    0.0
# 4           0.067398         0.075472           0.835905    1.0

# %%
md
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 3994    2
# 3995    2
# 3996    1
# 3997    0
# 3998    0
# Length: 3999, dtype: int32

# %%
data2=data.groupby(data.clust).mean()
data2
# Out:
#                 ID        Balance  Qual_miles  cc1_miles  cc2_miles  \
# clust
# 0      2284.375857   40747.617290   92.345809   1.092778   1.017923
# 1      1613.016089  108317.387376  198.336634   3.915842   1.001238
# 2      1904.763744   83529.153046  290.453195   1.156018   1.032689
# 3      1833.460548  118032.061192   73.112721   3.576490   1.001610
#
#        cc3_miles   Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# clust
# 0       1.004217   3335.152873     6.488666         226.599895
# 1       1.025990  45609.657178    20.201733         713.728960
# 2       1.008915   8850.395245    10.476969        1030.112927
# 3       1.022544  31282.666667    17.251208         225.352657
#
#        Flight_trans_12  Days_since_enroll  Award
# clust
# 0             0.658935        3619.111755    0.0
# 1             2.142327        4863.439356    1.0
# 2             3.148588        4338.867756    1.0
# 3             0.632850        4436.307568    0.0

# %%
data2=data.drop(['ID'],axis=1)
data2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data2.head()
# Out:
#    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    28143           0          1          1          1          174
# 1    19244           0          1          1          1          215
# 2    41354           0          1          1          1         4123
# 3    14776           0          1          1          1          500
# 4    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award  \
# 0            1                  0                0               7000      0
# 1            2                  0                0               6968      0
# 2            4                  0                0               7034      0
# 3            1                  0                0               6952      0
# 4           26               2077                4               6935      1
#
#    clust
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1

# %%
array=data2.values
array
# Out:
# array([[28143,     0,     1, ...,  7000,     0,     0],
#        [19244,     0,     1, ...,  6968,     0,     0],
#        [41354,     0,     1, ...,  7034,     0,     0],
#        ...,
#        [73597,     0,     3, ...,  1402,     1,     1],
#        [54899,     0,     1, ...,  1401,     0,     0],
#        [ 3016,     0,     1, ...,  1398,     0,     0]], dtype=int64)

# %%
stscaler=StandardScaler().fit(array)
X=stscaler.transform(array)
X
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#          1.39545434e+00, -7.66919299e-01, -8.93535871e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#          1.37995704e+00, -7.66919299e-01, -8.93535871e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#          1.41192021e+00, -7.66919299e-01, -8.93535871e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -1.31560393e+00,  1.30391816e+00, -4.00389487e-03],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -1.31608822e+00, -7.66919299e-01, -8.93535871e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -1.31754109e+00, -7.66919299e-01, -8.93535871e-01]])

# %%
dbscan=DBSCAN(eps=0.8,min_samples=6)
dbscan.fit(X)
# Out:
# DBSCAN(eps=0.8, min_samples=6)

# %%
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 2, 0, 0], dtype=int64)

# %%
c1=pd.DataFrame(dbscan.labels_,columns=['cluster'])
c1
# Out:
#       cluster
# 0           0
# 1           0
# 2           0
# 3           0
# 4          -1
# ...       ...
# 3994        1
# 3995        1
# 3996        2
# 3997        0
# 3998        0
#
# [3999 rows x 1 columns]

# %%
data3=pd.concat([c1,data2],axis=1)
data3
# Out:
#       cluster  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0           0    28143           0          1          1          1
# 1           0    19244           0          1          1          1
# 2           0    41354           0          1          1          1
# 3           0    14776           0          1          1          1
# 4          -1    97752           0          4          1          1
# ...       ...      ...         ...        ...        ...        ...
# 3994        1    18476           0          1          1          1
# 3995        1    64385           0          1          1          1
# 3996        2    73597           0          3          1          1
# 3997        0    54899           0          1          1          1
# 3998        0     3016           0          1          1          1
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# 0             174            1                  0                0
# ...

# %%
data3.cluster.value_counts()
# Out:
#  0    1719
# -1     822
#  2     510
#  3     495
#  1     434
#  4      12
#  5       7
# Name: cluster, dtype: int64

# %%
data4=data3.groupby(data3.cluster).mean()

# %%
data4
# Out:
#                Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# cluster
# -1       158302.812652  696.854015   2.669100   1.055961   1.059611
#  0        36134.467714    0.581734   1.091914   1.000000   1.000000
#  1        44657.850230    3.456221   1.158986   1.000000   1.000000
#  2        62894.833333    0.980392   3.721569   1.000000   1.000000
#  3       100785.109091    1.010101   3.496970   1.000000   1.000000
#  4        34516.083333    0.000000   1.000000   2.000000   1.000000
#  5        47279.000000    0.000000   3.000000   1.000000   1.000000
#
#           Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# cluster
# -1       35892.742092    20.163017        1800.675182         5.220195
#  0        2850.055846     6.013380          90.685282         0.314718
#  1        5596.529954     6.811060         235.380184         0.778802
#  2       34341.480392    16.776471         131.552941         0.429412
# ...
